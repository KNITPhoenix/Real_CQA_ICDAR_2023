# %%
import json
import os
import numpy as np
from scipy import stats as stats_mode
import shutil
import cv2
import random
import pandas as pd
import re
lst_of_folders = ['with_box']

# %%
random.seed(10)

# %%
def add_num(n):
    c=0
    i=n
    while(n>0):
        n=n//10
        c+=1
    if c==1 or c==3:
        if i%10 == 1:
            return "st"
        elif i%10 == 2:
            return "nd"
        elif i%10 == 3:
            return "rd"
        elif i%10 == 4:
            return "th"
        elif i%10 == 5:
            return "th"
        elif i%10 == 6:
            return "th"
        elif i%10 == 7:
            return "th"
        elif i%10 == 8:
            return "th"
        elif i%10 == 9:
            return "th"
    elif c==2:
        v=i%10
        if v==0:
            return "th"
        if v!=0:
            if i%10 == 1:
                return "st"
            elif i%10 == 2:
                return "nd"
            elif i%10 == 3:
                return "rd"
            elif i%10 == 4:
                return "th"
            elif i%10 == 5:
                return "th"
            elif i%10 == 6:
                return "th"
            elif i%10 == 7:
                return "th"
            elif i%10 == 8:
                return "th"
            elif i%10 == 9:
                return "th"

# %% [markdown]
# ## QA generation

# %%
for i in lst_of_folders:
    copy_folder = "C:/Users/pande/Desktop/test_2023/copy_JSON/"+i+"/"
    qa_folder = "C:/Users/pande/Desktop/test_2023/QA/"+i+"_qa/"
    if os.path.exists(qa_folder):
        shutil.rmtree(qa_folder)
    if not os.path.exists(qa_folder):
        os.mkdir(qa_folder)
    for file in os.listdir(copy_folder):
        qa=list()
        with open(copy_folder+file,'r') as f:
            js = json.load(f)
            
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' in js['task7'].keys():
                    if js['task7']['figure_type'] == 'boxplots':
                        legends = list()
                        if js['task7']['legends'] == js['task7']['name_of_data_series']:
                            legends = js['task7']['legends']
                        else:
                            legends = js['task7']['name_of_data_series']
                        st = "Which <X_label> for <legend_label> has the highest median of <Y_label>?"
                        st = st.replace("<X_label>","'"+js['task7']['x_label']+"'")
                        st = st.replace("<Y_label>","'"+js['task7']['y_label']+"'")
                        if len(legends)>1:
                            for i in legends:
                                ls_dat = dict()
                                for j in js['task6']['output']['data series']:
                                    if j['name'].split() == i.split():
                                        for j1 in j['data']:
                                            ls_dat[j1['x']] = j1['median']
                                ls_dat1 = sorted(ls_dat.items(),key = lambda x:x[1],reverse = True)
                                q=dict()
                                q['taxonomy id'] = '3b'
                                q['QID'] = str(130)
                                q['question'] = st.replace("<legend_label>","'"+i+"'")
                                ans = list()
                                for j in ls_dat1:
                                    if j[1]==ls_dat1[0][1]:
                                        ans.append(j[0])
                                q['answer'] = ",".join(ans)
                                qa.append(q)
                                
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Which <X_label> has the highest median of <Y_label>?"
                        st = st.replace("<Y_label>","'"+js['task7']['y_label']+"'")
                        st = st.replace("<X_label>","'"+js['task7']['x_label']+"'")
                        ls_dat = dict()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                ls_dat[j['x']] = j['median']
                        ls_dat1 = sorted(ls_dat.items(),key = lambda x:x[1],reverse = True)
                        answer_list = list()
                        for i in ls_dat1:
                            if i[1] == ls_dat1[0][1]:
                                answer_list.append(i[0])
                        q=dict()
                        q['taxonomy id'] = '3b'
                        q['QID'] = str(131)
                        q['question'] = st
                        q['answer'] = ",".join(answer_list)
                        qa.append(q)
                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Which <X_label> has the least median of <Y_label>?"
                        st = st.replace("<Y_label>","'"+js['task7']['y_label']+"'")
                        st = st.replace("<X_label>","'"+js['task7']['x_label']+"'")
                        ls_dat = dict()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                ls_dat[j['x']] = j['median']
                        ls_dat1 = sorted(ls_dat.items(),key = lambda x:x[1])
                        answer_list = list()
                        for i in ls_dat1:
                            if i[1] == ls_dat1[0][1]:
                                answer_list.append(i[0])
                        q=dict()
                        q['taxonomy id'] = '3b'
                        q['QID'] = str(132)
                        q['question'] = st
                        q['answer'] = ",".join(answer_list)
                        qa.append(q)
                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Which <X_label> has the highest upper quartile value of <Y_label>?"
                        st = st.replace("<Y_label>","'"+js['task7']['y_label']+"'")
                        st = st.replace("<X_label>","'"+js['task7']['x_label']+"'")
                        ls_dat = dict()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                ls_dat[j['x']] = j['third_quartile']
                        ls_dat1 = sorted(ls_dat.items(),key = lambda x:x[1],reverse = True)
                        answer_list = list()
                        for i in ls_dat1:
                            if i[1] == ls_dat1[0][1]:
                                answer_list.append(i[0])
                        q=dict()
                        q['taxonomy id'] = '3b'
                        q['QID'] = str(133)
                        q['question'] = st
                        q['answer'] = ",".join(answer_list)
                        qa.append(q)
                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Which <X_label> has the least upper quartile value of <Y_label>?"
                        st = st.replace("<Y_label>","'"+js['task7']['y_label']+"'")
                        st = st.replace("<X_label>","'"+js['task7']['x_label']+"'")
                        ls_dat = dict()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                ls_dat[j['x']] = j['third_quartile']
                        ls_dat1 = sorted(ls_dat.items(),key = lambda x:x[1])
                        answer_list = list()
                        for a in ls_dat1:
                            if a[1] == ls_dat1[0][1]:
                                answer_list.append(a[0])
                        q=dict()
                        q['taxonomy id'] = '3b'
                        q['QID'] = str(134)
                        q['question'] = st
                        q['answer'] = ",".join(answer_list)
                        qa.append(q)
                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Which <X_label> has the highest lower quartile value of <Y_label>?"
                        st = st.replace("<Y_label>","'"+js['task7']['y_label']+"'")
                        st = st.replace("<X_label>","'"+js['task7']['x_label']+"'")
                        ls_dat = dict()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                ls_dat[j['x']] = j['first_quartile']
                        ls_dat1 = sorted(ls_dat.items(),key = lambda x:x[1],reverse = True)
                        answer_list = list()
                        for i in ls_dat1:
                            if i[1] == ls_dat1[0][1]:
                                answer_list.append(i[0])
                        q=dict()
                        q['taxonomy id'] = '3b'
                        q['QID'] = str(135)
                        q['question'] = st
                        q['answer'] = ",".join(answer_list)
                        qa.append(q)
                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Which <X_label> has the least lower quartile value of <Y_label>?"
                        st = st.replace("<Y_label>","'"+js['task7']['y_label']+"'")
                        st = st.replace("<X_label>","'"+js['task7']['x_label']+"'")
                        ls_dat = dict()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                ls_dat[j['x']] = j['first_quartile']
                        ls_dat1 = sorted(ls_dat.items(),key = lambda x:x[1])
                        answer_list = list()
                        for i in ls_dat1:
                            if i[1] == ls_dat1[0][1]:
                                answer_list.append(i[0])
                        q=dict()
                        q['taxonomy id'] = '3b'
                        q['QID'] = str(136)
                        q['question'] = st
                        q['answer'] = ",".join(answer_list)
                        qa.append(q)
                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Which <X_label> has the least upper whisker value of <Y_label>?"
                        st = st.replace("<Y_label>","'"+js['task7']['y_label']+"'")
                        st = st.replace("<X_label>","'"+js['task7']['x_label']+"'")
                        ls_dat = dict()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                ls_dat[j['x']] = j['max']
                        ls_dat1 = sorted(ls_dat.items(),key = lambda x:x[1])
                        answer_list = list()
                        for i in ls_dat1:
                            if i[1] == ls_dat1[0][1]:
                                answer_list.append(i[0])
                        q=dict()
                        q['taxonomy id'] = '3b'
                        q['QID'] = str(137)
                        q['question'] = st
                        q['answer'] = ",".join(answer_list)
                        qa.append(q)
                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Which <X_label> has the highest upper whisker value of <Y_label>?"
                        st = st.replace("<Y_label>","'"+js['task7']['y_label']+"'")
                        st = st.replace("<X_label>","'"+js['task7']['x_label']+"'")
                        ls_dat = dict()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                ls_dat[j['x']] = j['max']
                        ls_dat1 = sorted(ls_dat.items(),key = lambda x:x[1],reverse = True)
                        answer_list = list()
                        for i in ls_dat1:
                            if i[1]==ls_dat1[0][1]:
                                answer_list.append(i[0])
                        q=dict()
                        q['taxonomy id'] = '3b'
                        q['QID'] = str(138)
                        q['question'] = st
                        q['answer'] = ",".join(answer_list)
                        qa.append(q)
                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Which <X_label> has the highest lower whisker value of <Y_label>?"
                        st = st.replace("<Y_label>","'"+js['task7']['y_label']+"'")
                        st = st.replace("<X_label>","'"+js['task7']['x_label']+"'")
                        ls_dat = dict()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                ls_dat[j['x']] = j['min']
                        ls_dat1 = sorted(ls_dat.items(),key = lambda x:x[1],reverse = True)
                        answer_list = list()
                        for i in ls_dat1:
                            if i[1]==ls_dat1[0][1]:
                                answer_list.append(i[0])
                        q=dict()
                        q['taxonomy id'] = '3b'
                        q['QID'] = str(139)
                        q['question'] = st
                        q['answer'] = ",".join(answer_list)
                        qa.append(q)
                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Which <X_label> has the least lower whisker value of <Y_label>?"
                        st = st.replace("<X_label>","'"+js['task7']['x_label']+"'")
                        st = st.replace("<Y_label>","'"+js['task7']['y_label']+"'")
                        ls_dat = dict()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                ls_dat[j['x']] = j['min']
                        ls_dat1 = sorted(ls_dat.items(),key = lambda x:x[1])
                        answer_list = list()
                        for i in ls_dat1:
                            if i[1]==ls_dat1[0][1]:
                                answer_list.append(i[0])
                        q=dict()
                        q['taxonomy id'] = '3b'
                        q['QID'] = str(140)
                        q['question'] = st
                        q['answer'] = ",".join(answer_list)
                        qa.append(q)
                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Which <X_label> has the highest inter-quartile range of <Y_label>?"
                        st = st.replace("<X_label>","'"+js['task7']['x_label']+"'")
                        st = st.replace("<Y_label>","'"+js['task7']['y_label']+"'")
                        ls_dat = dict()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                ls_dat[j['x']] = abs(j['first_quartile'] - j['third_quartile'])
                        ls_dat1 = sorted(ls_dat.items(),key = lambda x:x[1],reverse = True)
                        answer_list = list()
                        for i in ls_dat1:
                            if i[1]==ls_dat1[0][1]:
                                answer_list.append(i[0])
                        q=dict()
                        q['taxonomy id'] = '4b'
                        q['QID'] = str(141)
                        q['question'] = st
                        q['answer'] = ",".join(answer_list)
                        qa.append(q)
                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Which <X_label> has the least inter-quartile range of <Y_label>?"
                        st = st.replace("<X_label>","'"+js['task7']['x_label']+"'")
                        st = st.replace("<Y_label>","'"+js['task7']['y_label']+"'")
                        ls_dat = dict()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                ls_dat[j['x']] = abs(j['first_quartile'] - j['third_quartile'])
                        ls_dat1 = sorted(ls_dat.items(),key = lambda x:x[1])
                        answer_list = list()
                        for i in ls_dat1:
                            if i[1]==ls_dat1[0][1]:
                                answer_list.append(i[0])
                        q=dict()
                        q['taxonomy id'] = '4b'
                        q['QID'] = str(145)
                        q['question'] = st
                        q['answer'] = ",".join(answer_list)
                        qa.append(q)
                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Which <X_label> has the least extreme range of <Y_label>?"
                        st = st.replace("<X_label>","'"+js['task7']['x_label']+"'")
                        st = st.replace("<Y_label>","'"+js['task7']['y_label']+"'")
                        ls_dat = dict()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                ls_dat[j['x']] = abs(j['max'] - j['min'])
                        ls_dat1 = sorted(ls_dat.items(),key = lambda x:x[1])
                        answer_list = list()
                        for i in ls_dat1:
                            if i[1]==ls_dat1[0][1]:
                                answer_list.append(i[0])
                        q=dict()
                        q['taxonomy id'] = '4b'
                        q['QID'] = str(147)
                        q['question'] = st
                        q['answer'] = ",".join(answer_list)
                        qa.append(q)
                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Which <X_label> has the highest extreme range of <Y_label>?"
                        st = st.replace("<X_label>","'"+js['task7']['x_label']+"'")
                        st = st.replace("<Y_label>","'"+js['task7']['y_label']+"'")
                        ls_dat = dict()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                ls_dat[j['x']] = abs(j['max'] - j['min'])
                        ls_dat1 = sorted(ls_dat.items(),key = lambda x:x[1],reverse = True)
                        answer_list = list()
                        for i in ls_dat1:
                            if i[1]==ls_dat1[0][1]:
                                answer_list.append(i[0])
                        q=dict()
                        q['taxonomy id'] = '4b'
                        q['QID'] = str(148)
                        q['question'] = st
                        q['answer'] = ",".join(answer_list)
                        qa.append(q)
                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_ticks_from_left' in js['task7'].keys() and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        ticks = js['task7']['x_ticks_from_left']
                        st = 'Which <X_label> has upper quartile value same as that of <ith x_tick>?'
                        st = st.replace("<X_label>","'"+js['task7']['x_label']+"'")
                        for i in ticks:
                            for j in js['task6']['output']['data series']:
                                for k in j['data']:
                                    if k['x'].split() == i.split():
                                        quart = k['third_quartile']
                            ans = list()
                            for j in ticks:
                                if i!=j:
                                    for k in js['task6']['output']['data series']:
                                        for k1 in k['data']:
                                            if k1['x'].split() == j.split():
                                                if k1['third_quartile'] == quart:
                                                    ans.append(k1['x'])
                            if len(ans)!=0:
                                q = dict()
                                q['taxonomy id'] = '4b'
                                q['QID'] = str(142)
                                q['question'] = st.replace("<ith x_tick>","'"+i+"'")
                                q['answer'] = ",".join(ans)
                                qa.append(q)
                            
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_ticks_from_left' in js['task7'].keys() and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        ticks = js['task7']['x_ticks_from_left']
                        st = 'Which <X_label> has median same as that of <ith x_tick>?'
                        st = st.replace("<X_label>","'"+js['task7']['x_label']+"'")
                        for i in ticks:
                            for j in js['task6']['output']['data series']:
                                for k in j['data']:
                                    if k['x'].split() == i.split():
                                        quart = k['median']
                            ans = list()
                            for j in ticks:
                                if i!=j:
                                    for k in js['task6']['output']['data series']:
                                        for k1 in k['data']:
                                            if k1['x'].split() == j.split():
                                                if k1['median'] == quart:
                                                    ans.append(k1['x'])
                            if len(ans)!=0:
                                q = dict()
                                q['taxonomy id'] = '4b'
                                q['QID'] = str(143)
                                q['question'] = st.replace("<ith x_tick>","'"+i+"'")
                                q['answer'] = ",".join(ans)
                                qa.append(q)
                            
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_ticks_from_left' in js['task7'].keys() and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        ticks = js['task7']['x_ticks_from_left']
                        st = 'Which <plural form of X_label> have lower quartile value equal to upper quartile value as that at <ith x_tick>?'
                        st = st.replace("<plural form of X_label>","'"+js['task7']['x_label']+"'")
                        for i in ticks:
                            for j in js['task6']['output']['data series']:
                                for k in j['data']:
                                    if k['x'].split() == i.split():
                                        quart = k['third_quartile']
                            ans = list()
                            for j in ticks:
                                if i!=j:
                                    for k in js['task6']['output']['data series']:
                                        for k1 in k['data']:
                                            if k1['x'].split() == j.split():
                                                if k1['first_quartile'] == quart:
                                                    ans.append(k1['x'])
                            if len(ans)!=0:
                                q = dict()
                                q['taxonomy id'] = '4b'
                                q['QID'] = str(144)
                                q['question'] = st.replace("<ith x_tick>","'"+i+"'")
                                q['answer'] = ",".join(ans)
                                qa.append(q)
                            
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = 'Does any <plural form X_label> have equal interyers-quartile range?'
                        st = st.replace("<plural form X_label>","'"+js['task7']['x_label']+"'")
                        inter_dict = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                inter_dict.append([j['x'],abs(j['third_quartile']-j['first_quartile'])])
                        eq = list()
                        for i in range(len(inter_dict)-1):
                            for j in range(i+1,len(inter_dict)):
                                if inter_dict[i][1]==inter_dict[j][1]:
                                    eq.append([inter_dict[i][0],inter_dict[j][0]])
                        q=dict()
                        q['taxonomy id'] = '4b'
                        q['QID'] = str(146)
                        q['question'] = st
                        q['answer'] = 'yes' if len(eq)!=0 else 'no'
                        qa.append(q)
                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = 'What <plural form X_label> have equal inter-quartile range?'
                        st = st.replace("<plural form X_label>","'"+js['task7']['x_label']+"'")
                        inter_dict = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                inter_dict.append([j['x'],abs(j['third_quartile']-j['first_quartile'])])
                        eq = list()
                        for i in range(len(inter_dict)-1):
                            for j in range(i+1,len(inter_dict)):
                                if inter_dict[i][1]==inter_dict[j][1]:
                                    eq.append([inter_dict[i][0],inter_dict[j][0]])
                        if len(eq)!=0:
                            q=dict()
                            q['taxonomy id'] = '4b'
                            q['QID'] = '146a'
                            q['question'] = st
                            q['answer'] = tuple(eq)
                            qa.append(q)
                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_ticks_from_left' in js['task7'].keys() and 'legends' in js['task7'].keys():
                    if js['task7']['figure_type'] == 'boxplots':
                        legends = list()
                        if js['task7']['legends'] == js['task7']['name_of_data_series']:
                            legends = js['task7']['legends']
                        else:
                            legends = js['task7']['name_of_data_series']
                        st = "Between <ith x_tick> and <jth x_tick> of <legend-label>, which one has the higher upper extreme value?"
                        ticks = js['task7']['x_ticks_from_left']
                        if len(legends)>1:
                            for i in legends:
                                for j in range(len(ticks)-1):
                                    for k in range(j+1,len(ticks)):
                                        for i1 in js['task6']['output']['data series']:
                                            if i1['name'].split() == i.split():
                                                for i2 in i1['data']:
                                                    if i2['x'].split() == ticks[j].split():
                                                        dat1 = i2['max']
                                                    elif i2['x'].split() == ticks[k].split():
                                                        dat2 = i2['max']
                                        q=dict()
                                        q['taxonomy id'] = '4b'
                                        q['QID'] = str(149)
                                        qu = st.replace("<ith x_tick>","'"+ticks[j]+"'")
                                        qu = qu.replace("<jth x_tick>","'"+ticks[k]+"'")
                                        q['question'] = qu.replace("<legend-label>",i)
                                        q['answer'] = ticks[j] if dat1>dat2 else ticks[k]
                                        qa.append(q)
                                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_ticks_from_left' in js['task7'].keys() and 'legends' in js['task7'].keys():
                    if js['task7']['figure_type'] == 'boxplots':
                        legends = list()
                        if js['task7']['legends'] == js['task7']['name_of_data_series']:
                            legends = js['task7']['legends']
                        else:
                            legends = js['task7']['name_of_data_series']
                        st = "Is the data skewed or normally distributed for <legend-label> at <ith xtick>?"
                        ticks = js['task7']['x_ticks_from_left']
                        if len(legends)>1:
                            for i in legends:
                                qu = st.replace("<legend-label>",i)
                                for j in ticks:
                                    for k in js['task6']['output']['data series']:
                                        if k['name'].split() == i.split():
                                            for k1 in k['data']:
                                                if k1['x'].split() == j.split():
                                                    f=0
                                                    d1 = abs(k1['first_quartile'] - k1['median'])
                                                    d2 = abs(k1['third_quartile'] - k1['median'])
                                                    d1 = round(d1,3)
                                                    d2 = round(d2,3)
                                                    if d1<d2:
                                                        skw = "Positively Skewed"
                                                        f=1
                                                    elif d2<d1:
                                                        skw = "Negatively Skewed"
                                                        f=1
                                                    elif d1==d2:
                                                        f=0
                                                        skw = "Normally Distributed"
                                    q=dict()
                                    q['taxonomy id'] = '4b'
                                    q['QID'] = str(150)
                                    q['question'] = qu.replace("<ith xtick>",j)
                                    q['answer'] = "Skewed" if f==1 else "Normally Distributed"
                                    qa.append(q)
                                    
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_ticks_from_left' in js['task7'].keys() and 'legends' in js['task7'].keys():
                    if js['task7']['figure_type'] == 'boxplots':
                        legends = list()
                        if js['task7']['legends'] == js['task7']['name_of_data_series']:
                            legends = js['task7']['legends']
                        else:
                            legends = js['task7']['name_of_data_series']
                        st = "How is the data skewed for <legend-label> at <ith xtick>?"
                        ticks = js['task7']['x_ticks_from_left']
                        if len(legends)>1:
                            for i in legends:
                                qu = st.replace("<legend-label>",i)
                                for j in ticks:
                                    for k in js['task6']['output']['data series']:
                                        if k['name'].split() == i.split():
                                            for k1 in k['data']:
                                                if k1['x'].split() == j.split():
                                                    f=0
                                                    d1 = abs(k1['first_quartile'] - k1['median'])
                                                    d2 = abs(k1['third_quartile'] - k1['median'])
                                                    d1 = round(d1,3)
                                                    d2 = round(d2,3)
                                                    if d1<d2:
                                                        skw = "Positively Skewed"
                                                        f=1
                                                    elif d2<d1:
                                                        skw = "Negatively Skewed"
                                                        f=2
                                                    elif d1==d2:
                                                        f=0
                                                        skw = "Normally Distributed"
                                    if f!=0:
                                        q=dict()
                                        q['taxonomy id'] = '4b'
                                        q['QID'] = str(151)
                                        q['question'] = qu.replace("<ith xtick>",j)
                                        q['answer'] = skw
                                        qa.append(q)
                                        
            if 'task1' in js.keys():
                if js['task1']!=None:
                    title_horizontal = "yes" if "horizontal" in js['task1']['output']['chart_type'].split(" ") else "no"
                    
            if 'task7' in js.keys():
                if 'are_there_zero_values' in js['task7'].keys() and 'figure_type' in js['task7'].keys():
                    if js['task7']['figure_type'] == 'boxplots':
                        q=dict()
                        q['taxonomy id'] = '3a'
                        q['QID'] = str(1)
                        q['question'] = "Does the chart contain any zero data values?"
                        q['answer'] = js['task7']['are_there_zero_values']
                        qa.append(q)
                        
            if 'task7' in js.keys():
                if 'legend_position' in js['task7'].keys() :
                    q=dict()
                    q['taxonomy id'] = '2e'
                    q['QID'] = str(3)
                    q['question'] = "Where does the legend appear in the chart?"
                    q['answer'] = js['task7']['legend_position']
                    qa.append(q)
                    
            if 'task7' in js.keys():
                if 'legend_length' in js['task7'].keys() :
                    q=dict()
                    q['taxonomy id'] = '2g'
                    q['QID'] = str(4)
                    q['question'] = "How many legend labels are there?"
                    q['answer'] = js['task7']['legend_length']
                    qa.append(q)
                    
            if 'task7' in js.keys():
                if 'legend_labels_orientation' in js['task7'].keys() :
                    q=dict()
                    q['taxonomy id'] = '2g'
                    q['QID'] = str(5)
                    q['question'] = "What is the orientation of legend labels?"
                    q['answer'] = js['task7']['legend_labels_orientation']
                    qa.append(q)
                    
            if 'task7' in js.keys():
                if 'x_label_presence' in js['task7'].keys() and 'figure_type' in js['task7'].keys():
                    if js['task7']['figure_type'] == 'boxplots':
                        if js['task7']['x_label_presence']:
                            q=dict()
                            q['taxonomy id'] = '2b'
                            q['QID'] = str(6)
                            st = "How many <plural form of X title> are there in the chart?"
                            q['question'] = st.replace("<plural form of X title>","'"+js['task7']['x_label']+"'")
                            q['answer'] = js['task7']['number_of_x_ticks']
                            qa.append(q)
                            
            if 'task7' in js.keys():
                if 'x_ticks_from_left' in js['task7'].keys():
                    q=dict()
                    q['taxonomy id'] = '2b'
                    q['QID'] = '6b'
                    q['question'] = "List all the major ticks on independent axis from left?"
                    q['answer'] = tuple(js['task7']['x_ticks_from_left'])
                    qa.append(q)
                        
            if 'task7' in js.keys():
                if 'x_ticks_from_right' in js['task7'].keys():
                    q=dict()
                    q['taxonomy id'] = '2b'
                    q['QID'] = '6c'
                    q['question'] = "List all the major ticks on independent axis from right?"
                    q['answer'] = tuple(js['task7']['x_ticks_from_right'])
                    qa.append(q)

            if 'task7' in js.keys():
                if 'x_ticks_from_top' in js['task7'].keys():
                    q=dict()
                    q['taxonomy id'] = '2b'
                    q['QID'] = '6d'
                    q['question'] = "List all the major ticks on independent axis from top?"
                    q['answer'] = tuple(js['task7']['x_ticks_from_top'])
                    qa.append(q)

            if 'task7' in js.keys():
                if 'x_ticks_from_bottom' in js['task7'].keys():
                    q=dict()
                    q['taxonomy id'] = '2b'
                    q['QID'] = '6e'
                    q['question'] = "List all the major ticks on independent axis from bottom?"
                    q['answer'] = tuple(js['task7']['x_ticks_from_bottom'])
                    qa.append(q)
                            
            if 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None:
                    if js['task7']['figure_type'] == 'boxplots':
                        c=0
                        for i in js['task6']['output']['data series']:
                            c+=len(i['data'])
                        q=dict()
                        q['taxonomy id'] = '3a'
                        q['QID'] = str(7)
                        st = "How many <figure-type>s are visually present?"
                        q['question'] = st.replace("<figure-type>s",js['task7']['figure_type'])
                        q['answer'] = c
                        qa.append(q)
                        
            if 'task1' in js.keys() and 'task7' in js.keys():
                if js['task1']!=None and 'figure_type' in js['task7'].keys():
                    if js['task7']['figure_type'] == 'boxplots':
                        q=dict()
                        q['taxonomy id'] = '2j'
                        q['QID'] = str(152)
                        q['question'] = "What is the orientation of boxes in the chart?"
                        q['answer'] = "Horizontal" if title_horizontal == 'yes' else 'Vertical'
                        qa.append(q)
                        
            if 'task7' in js.keys():
                if 'y_ticks_from_bottom' in js['task7'].keys():
                    if len(js['task7']['y_ticks_from_bottom'])>1:
                        q=dict()
                        q['taxonomy id'] = '2c'
                        q['QID'] = str(26)
                        q['question'] = 'What is the difference between two consecutive major ticks of the dependant variable?'
                        tick_lst = list()
                        ticks = js['task7']['y_ticks_from_bottom']
                        for i in ticks:
                            try:
                                tick_lst.append(float(i))
                            except:
                                pass
                        if len(tick_lst)>1:
                            diff = list()
                            for i in range(len(tick_lst)-1):
                                diff.append(abs(tick_lst[i+1]-tick_lst[i]))
                            flag = 'Linear' if all(x in [diff[0],diff[0]+1,diff[0]-1] for x in diff) else 'Logarithmic'
                            if flag == 'Linear' and len(diff)>0:
                                q['answer'] = diff[0]
                                qa.append(q)
                elif 'y_ticks_from_left' in js['task7'].keys():
                    if len(js['task7']['y_ticks_from_left'])>1:
                        q=dict()
                        q['taxonomy id'] = '2c'
                        q['QID'] = str(26)
                        q['question'] = 'What is the difference between two consecutive major ticks of the dependant variable?'
                        tick_lst = list()
                        ticks = js['task7']['y_ticks_from_left']
                        for i in ticks:
                            try:
                                tick_lst.append(float(i))
                            except:
                                pass
                        if len(tick_lst)!=0:
                            diff = list()
                            for i in range(len(tick_lst)-1):
                                diff.append(abs(tick_lst[i+1]-tick_lst[i]))
                            flag = 'Linear' if all(x in [diff[0],diff[0]+1,diff[0]-1] for x in diff) else 'Logarithmic'
                            if flag == 'Linear' and len(diff)>0:
                                q['answer'] = diff[0]
                                qa.append(q)
                        
            if 'task7' in js.keys():
                if 'y_ticks_from_bottom' in js['task7'].keys():
                    if len(js['task7']['y_ticks_from_bottom'])>1:
                        q=dict()
                        q['taxonomy id'] = '2c'
                        q['QID'] = str(27)
                        q['question'] = 'Are the values on the major ticks of dependent axis written in scientific E-notation?'
                        y_text = js['task7']['y_ticks_from_bottom']
                        ans=list()
                        for i in y_text:
                            if 'e' in i.lower():
                                ans.append("e")
                            else:
                                ans.append("n")
                        q['answer'] = "yes" if all(i=="e" for i in ans) else "no"
                        qa.append(q)
                elif 'y_ticks_from_left' in js['task7'].keys():
                    if len(js['task7']['y_ticks_from_left'])>1:
                        q=dict()
                        q['taxonomy id'] = '2c'
                        q['QID'] = str(27)
                        q['question'] = 'Are the values on the major ticks of dependent axis written in scientific E-notation?'
                        y_text = js['task7']['y_ticks_from_left']
                        ans=list()
                        for i in y_text:
                            if 'e' in i.lower():
                                ans.append("e")
                            else:
                                ans.append("n")
                        q['answer'] = "yes" if all(i=="e" for i in ans) else "no"
                        qa.append(q)
                        
            if 'task7' in js.keys():
                q=dict()
                q['taxonomy id'] = '1a'
                q['QID'] = '28a'
                q['question'] = 'Is there a title in the chart?'
                if 'chart_title' in js['task7'].keys():
                    q['answer'] = 'yes'
                else:
                    q['answer'] = 'no'
                qa.append(q)
                
            if 'task7' in js.keys():
                if 'chart_title' in js['task7'].keys():
                    q=dict()
                    q['taxonomy id'] = '1a'
                    q['QID'] = str(28)
                    q['question'] = 'What is the title of the chart?'
                    q['answer'] = js['task7']['chart_title']
                    qa.append(q)
                    
            if 'task7' in js.keys():
                questions = list()
                answers = list()
                st = "Does <legend_label/x_label/y-label> appear as one of the legend labels in the graph?"
                if 'legends' in js['task7'].keys():
                    for i in js['task7']['legends']:
                        questions.append(st.replace("<legend_label/x_label/y-label>",i))
                        answers.append("yes")
                if 'x_label' in js['task7'].keys():
                    questions.append(st.replace("<legend_label/x_label/y-label>","'"+js['task7']['x_label']+"'"))
                    answers.append("no")
                if 'y_label' in js['task7'].keys():
                    questions.append(st.replace("<legend_label/x_label/y-label>","'"+js['task7']['y_label']+"'"))
                    answers.append("no")
                if len(questions)!=0:
                    for i in range(len(questions)):
                        q=dict()
                        q['taxonomy id'] = '2g'
                        q['QID'] = str(29)
                        q['question'] = questions[i]
                        q['answer'] = answers[i]
                        qa.append(q)
                        
            if 'task7' in js.keys():
                if 'x_label' in js['task7'].keys():
                    q=dict()
                    q['taxonomy id'] = '2a'
                    q['QID'] = str(30)
                    q['question'] = "What is the label or title of the independent axis?"
                    q['answer'] = js['task7']['x_label']
                    qa.append(q)
                    
            if 'task7' in js.keys():
                if 'y_label' in js['task7'].keys():
                    q=dict()
                    q['taxonomy id'] = '2c'
                    q['QID'] = str(31)
                    q['question'] = "What is the label or title of the dependent axis?"
                    q['answer'] = js['task7']['y_label']
                    qa.append(q)
                    
            if 'task1' in js.keys():
                if js['task1']!=None:
                    q=dict()
                    q['taxonomy id'] = '1a'
                    q['QID'] = '7a'
                    q['question'] = "What is the type of chart?"
                    if 'bar' in js['task1']['output']['chart_type'].split():
                        if title_horizontal == "yes":
                            q['answer'] = 'Horizontal Bar chart'
                        else:
                            q['answer'] = 'Vertical Bar chart'
                    elif 'line' in js['task1']['output']['chart_type'].split():
                        q['answer'] = 'Line chart'
                    elif 'scatter' in js['task1']['output']['chart_type'].split():
                        q['answer'] = 'Scatter chart'
                    elif 'box' in js['task1']['output']['chart_type'].split():
                        if title_horizontal == "yes":
                            q['answer'] = 'Horizontal Boxplots'
                        else:
                            q['answer'] = 'Vertical Boxplots'
                    qa.append(q)
                    
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "In how many <plural form of X title>, is the median greater than <N> units?"
                        st = st.replace("<plural form of X title>",js['task7']['x_label'])
                        med_lst = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append(j['median'])
                        N = random.uniform(min(med_lst),max(med_lst))
                        q=dict()
                        q['taxonomy id'] = '4b'
                        q['QID'] = str(154)
                        q['question'] = st.replace("<N> units",str(N))
                        count = 0
                        for i in med_lst:
                            if i>N:
                                count+=1
                        q['answer'] = count
                        qa.append(q)
                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "For what <plural form of X title> are the median greater than <N> units?"
                        st = st.replace("<plural form of X title>",js['task7']['x_label'])
                        med_lst = list()
                        data_list = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append(j['median'])
                                data_list.append([j['x'],j['median']])
                        N = random.uniform(min(med_lst),max(med_lst))
                        answers_list = list()
                        for i in data_list:
                            if i[1]>N:
                                answers_list.append(i[0])
                        if len(answers_list)!=0:
                            q=dict()
                            q['taxonomy id'] = '4b'
                            q['QID'] = '154a'
                            q['question'] = st.replace("<N> units",str(N))
                            q['answer'] = tuple(answers_list)
                            qa.append(q)
                            
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "What <plural form of X title> have the median greater than <N> units, arranged in increasing order of difference between median and <N> units?"
                        st = st.replace("<plural form of X title>",js['task7']['x_label'])
                        med_lst = list()
                        data_list = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append(j['median'])
                                data_list.append([j['x'],j['median']])
                        N = random.uniform(min(med_lst),max(med_lst))
                        answers_list_temp = list()
                        for i in data_list:
                            if i[1]>N:
                                answers_list_temp.append([i[0],abs(i[1]-N)])
                        answers_list_temp = sorted(answers_list_temp,key = lambda x:x[1])
                        answers_list = list()
                        for i in answers_list_temp:
                            answers_list.append(i[0])
                        if len(answers_list)!=0:
                            q=dict()
                            q['taxonomy id'] = '4b'
                            q['QID'] = '154b'
                            q['question'] = st.replace("<N> units",str(N))
                            q['answer'] = tuple(answers_list)
                            qa.append(q)
            
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "In how many <plural form of X title>, is the upper quartile greater than <N> units?"
                        st = st.replace("<plural form of X title>",js['task7']['x_label'])
                        med_lst = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append(j['third_quartile'])
                        N = random.uniform(min(med_lst),max(med_lst))
                        q=dict()
                        q['taxonomy id'] = '4b'
                        q['QID'] = str(155)
                        q['question'] = st.replace("<N> units",str(N))
                        count = 0
                        for i in med_lst:
                            if i>N:
                                count+=1
                        q['answer'] = count
                        qa.append(q)
                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "For what <plural form of X title> are the upper quartile greater than <N> units?"
                        st = st.replace("<plural form of X title>",js['task7']['x_label'])
                        med_lst = list()
                        data_list = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append(j['third_quartile'])
                                data_list.append([j['x'],j['third_quartile']])
                        N = random.uniform(min(med_lst),max(med_lst))
                        answers_list = list()
                        for i in data_list:
                            if i[1]>N:
                                answers_list.append(i[0])
                        if len(answers_list)!=0:
                            q=dict()
                            q['taxonomy id'] = '4b'
                            q['QID'] = '155a'
                            q['question'] = st.replace("<N> units",str(N))
                            q['answer'] = tuple(answers_list)
                            qa.append(q)
                            
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "What <plural form of X title> have the upper quartile greater than <N> units, arranged in increasing order of difference between upper quartile and <N> units?"
                        st = st.replace("<plural form of X title>",js['task7']['x_label'])
                        med_lst = list()
                        data_list = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append(j['third_quartile'])
                                data_list.append([j['x'],j['third_quartile']])
                        N = random.uniform(min(med_lst),max(med_lst))
                        answers_list_temp = list()
                        for i in data_list:
                            if i[1]>N:
                                answers_list_temp.append([i[0],abs(i[1]-N)])
                        answers_list_temp = sorted(answers_list_temp,key = lambda x:x[1])
                        answers_list = list()
                        for i in answers_list_temp:
                            answers_list.append(i[0])
                        if len(answers_list)!=0:
                            q=dict()
                            q['taxonomy id'] = '4b'
                            q['QID'] = '155b'
                            q['question'] = st.replace("<N> units",str(N))
                            q['answer'] = tuple(answers_list)
                            qa.append(q)
                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "In how many <plural form of X title>, is the lower quartile greater than <N> units?"
                        st = st.replace("<plural form of X title>",js['task7']['x_label'])
                        med_lst = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append(j['first_quartile'])
                        N = random.uniform(min(med_lst),max(med_lst))
                        q=dict()
                        q['taxonomy id'] = '4b'
                        q['QID'] = str(156)
                        q['question'] = st.replace("<N> units",str(N))
                        count = 0
                        for i in med_lst:
                            if i>N:
                                count+=1
                        q['answer'] = count
                        qa.append(q)
                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "For what <plural form of X title> are the lower quartile greater than <N> units?"
                        st = st.replace("<plural form of X title>",js['task7']['x_label'])
                        med_lst = list()
                        data_list = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append(j['first_quartile'])
                                data_list.append([j['x'],j['first_quartile']])
                        N = random.uniform(min(med_lst),max(med_lst))
                        answers_list = list()
                        for i in data_list:
                            if i[1]>N:
                                answers_list.append(i[0])
                        if len(answers_list)!=0:
                            q=dict()
                            q['taxonomy id'] = '4b'
                            q['QID'] = '156a'
                            q['question'] = st.replace("<N> units",str(N))
                            q['answer'] = tuple(answers_list)
                            qa.append(q)
                            
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "What <plural form of X title> have the lower quartile greater than <N> units, arranged in increasing order of difference between lower quartile and <N> units?"
                        st = st.replace("<plural form of X title>",js['task7']['x_label'])
                        med_lst = list()
                        data_list = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append(j['first_quartile'])
                                data_list.append([j['x'],j['first_quartile']])
                        N = random.uniform(min(med_lst),max(med_lst))
                        answers_list_temp = list()
                        for i in data_list:
                            if i[1]>N:
                                answers_list_temp.append([i[0],abs(i[1]-N)])
                        answers_list_temp = sorted(answers_list_temp,key = lambda x:x[1])
                        answers_list = list()
                        for i in answers_list_temp:
                            answers_list.append(i[0])
                        if len(answers_list)!=0:
                            q=dict()
                            q['taxonomy id'] = '4b'
                            q['QID'] = '156b'
                            q['question'] = st.replace("<N> units",str(N))
                            q['answer'] = tuple(answers_list)
                            qa.append(q)
                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "In how many <plural form of X title>, is the maximum value greater than <N> units?"
                        st = st.replace("<plural form of X title>",js['task7']['x_label'])
                        med_lst = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append(j['max'])
                        N = random.uniform(min(med_lst),max(med_lst))
                        q=dict()
                        q['taxonomy id'] = '4b'
                        q['QID'] = str(157)
                        q['question'] = st.replace("<N> units",str(N))
                        count = 0
                        for i in med_lst:
                            if i>N:
                                count+=1
                        q['answer'] = count
                        qa.append(q)
                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "For what <plural form of X title> are the maximum value greater than <N> units?"
                        st = st.replace("<plural form of X title>",js['task7']['x_label'])
                        med_lst = list()
                        data_list = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append(j['max'])
                                data_list.append([j['x'],j['max']])
                        N = random.uniform(min(med_lst),max(med_lst))
                        answers_list = list()
                        for i in data_list:
                            if i[1]>N:
                                answers_list.append(i[0])
                        if len(answers_list)!=0:
                            q=dict()
                            q['taxonomy id'] = '4b'
                            q['QID'] = '157a'
                            q['question'] = st.replace("<N> units",str(N))
                            q['answer'] = tuple(answers_list)
                            qa.append(q)
                            
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "What <plural form of X title> have the maximum value greater than <N> units, arranged in increasing order of difference between maximum value and <N> units?"
                        st = st.replace("<plural form of X title>",js['task7']['x_label'])
                        med_lst = list()
                        data_list = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append(j['max'])
                                data_list.append([j['x'],j['max']])
                        N = random.uniform(min(med_lst),max(med_lst))
                        answers_list_temp = list()
                        for i in data_list:
                            if i[1]>N:
                                answers_list_temp.append([i[0],abs(i[1]-N)])
                        answers_list_temp = sorted(answers_list_temp,key = lambda x:x[1])
                        answers_list = list()
                        for i in answers_list_temp:
                            answers_list.append(i[0])
                        if len(answers_list)!=0:
                            q=dict()
                            q['taxonomy id'] = '4b'
                            q['QID'] = '157b'
                            q['question'] = st.replace("<N> units",str(N))
                            q['answer'] = tuple(answers_list)
                            qa.append(q)
                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "In how many <plural form of X title>, is the minimum value greater than <N> units?"
                        st = st.replace("<plural form of X title>",js['task7']['x_label'])
                        med_lst = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append(j['min'])
                        N = random.uniform(min(med_lst),max(med_lst))
                        q=dict()
                        q['taxonomy id'] = '4b'
                        q['QID'] = str(158)
                        q['question'] = st.replace("<N> units",str(N))
                        count = 0
                        for i in med_lst:
                            if i>N:
                                count+=1
                        q['answer'] = count
                        qa.append(q)
                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "For what <plural form of X title> are the minimum value greater than <N> units?"
                        st = st.replace("<plural form of X title>",js['task7']['x_label'])
                        med_lst = list()
                        data_list = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append(j['min'])
                                data_list.append([j['x'],j['min']])
                        N = random.uniform(min(med_lst),max(med_lst))
                        answers_list = list()
                        for i in data_list:
                            if i[1]>N:
                                answers_list.append(i[0])
                        if len(answers_list)!=0:
                            q=dict()
                            q['taxonomy id'] = '4b'
                            q['QID'] = '158a'
                            q['question'] = st.replace("<N> units",str(N))
                            q['answer'] = tuple(answers_list)
                            qa.append(q)
                            
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "What <plural form of X title> have the minimum value greater than <N> units, arranged in increasing order of difference between minimum value and <N> units?"
                        st = st.replace("<plural form of X title>",js['task7']['x_label'])
                        med_lst = list()
                        data_list = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append(j['min'])
                                data_list.append([j['x'],j['min']])
                        N = random.uniform(min(med_lst),max(med_lst))
                        answers_list_temp = list()
                        for i in data_list:
                            if i[1]>N:
                                answers_list_temp.append([i[0],abs(i[1]-N)])
                        answers_list_temp = sorted(answers_list_temp,key = lambda x:x[1])
                        answers_list = list()
                        for i in answers_list_temp:
                            answers_list.append(i[0])
                        if len(answers_list)!=0:
                            q=dict()
                            q['taxonomy id'] = '4b'
                            q['QID'] = '158b'
                            q['question'] = st.replace("<N> units",str(N))
                            q['answer'] = tuple(answers_list)
                            qa.append(q)
                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "In how many <plural form of X title>, is the median less than <N> units?"
                        st = st.replace("<plural form of X title>",js['task7']['x_label'])
                        med_lst = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append(j['median'])
                        N = random.uniform(min(med_lst),max(med_lst))
                        q=dict()
                        q['taxonomy id'] = '4b'
                        q['QID'] = str(159)
                        q['question'] = st.replace("<N> units",str(N))
                        count = 0
                        for i in med_lst:
                            if i<N:
                                count+=1
                        q['answer'] = count
                        qa.append(q)
                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "For what <plural form of X title> are the median less than <N> units?"
                        st = st.replace("<plural form of X title>",js['task7']['x_label'])
                        med_lst = list()
                        data_list = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append(j['median'])
                                data_list.append([j['x'],j['median']])
                        N = random.uniform(min(med_lst),max(med_lst))
                        answers_list = list()
                        for i in data_list:
                            if i[1]<N:
                                answers_list.append(i[0])
                        if len(answers_list)!=0:
                            q=dict()
                            q['taxonomy id'] = '4b'
                            q['QID'] = '159a'
                            q['question'] = st.replace("<N> units",str(N))
                            q['answer'] = tuple(answers_list)
                            qa.append(q)
                            
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "What <plural form of X title> have the median less than <N> units, arranged in increasing order of difference between median and <N> units?"
                        st = st.replace("<plural form of X title>",js['task7']['x_label'])
                        med_lst = list()
                        data_list = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append(j['median'])
                                data_list.append([j['x'],j['median']])
                        N = random.uniform(min(med_lst),max(med_lst))
                        answers_list_temp = list()
                        for i in data_list:
                            if i[1]<N:
                                answers_list_temp.append([i[0],abs(i[1]-N)])
                        answers_list_temp = sorted(answers_list_temp,key = lambda x:x[1])
                        answers_list = list()
                        for i in answers_list_temp:
                            answers_list.append(i[0])
                        if len(answers_list)!=0:
                            q=dict()
                            q['taxonomy id'] = '4b'
                            q['QID'] = '159b'
                            q['question'] = st.replace("<N> units",str(N))
                            q['answer'] = tuple(answers_list)
                            qa.append(q)
            
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "In how many <plural form of X title>, is the upper quartile less than <N> units?"
                        st = st.replace("<plural form of X title>",js['task7']['x_label'])
                        med_lst = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append(j['third_quartile'])
                        N = random.uniform(min(med_lst),max(med_lst))
                        q=dict()
                        q['taxonomy id'] = '4b'
                        q['QID'] = str(160)
                        q['question'] = st.replace("<N> units",str(N))
                        count = 0
                        for i in med_lst:
                            if i<N:
                                count+=1
                        q['answer'] = count
                        qa.append(q)
                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "For what <plural form of X title> are the upper quartile less than <N> units?"
                        st = st.replace("<plural form of X title>",js['task7']['x_label'])
                        med_lst = list()
                        data_list = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append(j['third_quartile'])
                                data_list.append([j['x'],j['third_quartile']])
                        N = random.uniform(min(med_lst),max(med_lst))
                        answers_list = list()
                        for i in data_list:
                            if i[1]<N:
                                answers_list.append(i[0])
                        if len(answers_list)!=0:
                            q=dict()
                            q['taxonomy id'] = '4b'
                            q['QID'] = '160a'
                            q['question'] = st.replace("<N> units",str(N))
                            q['answer'] = tuple(answers_list)
                            qa.append(q)
                            
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "What <plural form of X title> have the upper quartile less than <N> units, arranged in increasing order of difference between upper quartile and <N> units?"
                        st = st.replace("<plural form of X title>",js['task7']['x_label'])
                        med_lst = list()
                        data_list = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append(j['third_quartile'])
                                data_list.append([j['x'],j['third_quartile']])
                        N = random.uniform(min(med_lst),max(med_lst))
                        answers_list_temp = list()
                        for i in data_list:
                            if i[1]<N:
                                answers_list_temp.append([i[0],abs(i[1]-N)])
                        answers_list_temp = sorted(answers_list_temp,key = lambda x:x[1])
                        answers_list = list()
                        for i in answers_list_temp:
                            answers_list.append(i[0])
                        if len(answers_list)!=0:
                            q=dict()
                            q['taxonomy id'] = '4b'
                            q['QID'] = '160b'
                            q['question'] = st.replace("<N> units",str(N))
                            q['answer'] = tuple(answers_list)
                            qa.append(q)
                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "In how many <plural form of X title>, is the lower quartile less than <N> units?"
                        st = st.replace("<plural form of X title>",js['task7']['x_label'])
                        med_lst = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append(j['first_quartile'])
                        N = random.uniform(min(med_lst),max(med_lst))
                        q=dict()
                        q['taxonomy id'] = '4b'
                        q['QID'] = str(161)
                        q['question'] = st.replace("<N> units",str(N))
                        count = 0
                        for i in med_lst:
                            if i<N:
                                count+=1
                        q['answer'] = count
                        qa.append(q)
                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "For what <plural form of X title> are the lower quartile less than <N> units?"
                        st = st.replace("<plural form of X title>",js['task7']['x_label'])
                        med_lst = list()
                        data_list = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append(j['first_quartile'])
                                data_list.append([j['x'],j['first_quartile']])
                        N = random.uniform(min(med_lst),max(med_lst))
                        answers_list = list()
                        for i in data_list:
                            if i[1]<N:
                                answers_list.append(i[0])
                        if len(answers_list)!=0:
                            q=dict()
                            q['taxonomy id'] = '4b'
                            q['QID'] = '161a'
                            q['question'] = st.replace("<N> units",str(N))
                            q['answer'] = tuple(answers_list)
                            qa.append(q)
                            
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "What <plural form of X title> have the lower quartile less than <N> units, arranged in increasing order of difference between lower quartile and <N> units?"
                        st = st.replace("<plural form of X title>",js['task7']['x_label'])
                        med_lst = list()
                        data_list = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append(j['first_quartile'])
                                data_list.append([j['x'],j['first_quartile']])
                        N = random.uniform(min(med_lst),max(med_lst))
                        answers_list_temp = list()
                        for i in data_list:
                            if i[1]<N:
                                answers_list_temp.append([i[0],abs(i[1]-N)])
                        answers_list_temp = sorted(answers_list_temp,key = lambda x:x[1])
                        answers_list = list()
                        for i in answers_list_temp:
                            answers_list.append(i[0])
                        if len(answers_list)!=0:
                            q=dict()
                            q['taxonomy id'] = '4b'
                            q['QID'] = '161b'
                            q['question'] = st.replace("<N> units",str(N))
                            q['answer'] = tuple(answers_list)
                            qa.append(q)
                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "In how many <plural form of X title>, is the maximum value less than <N> units?"
                        st = st.replace("<plural form of X title>",js['task7']['x_label'])
                        med_lst = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append(j['max'])
                        N = random.uniform(min(med_lst),max(med_lst))
                        q=dict()
                        q['taxonomy id'] = '4b'
                        q['QID'] = str(162)
                        q['question'] = st.replace("<N> units",str(N))
                        count = 0
                        for i in med_lst:
                            if i<N:
                                count+=1
                        q['answer'] = count
                        qa.append(q)
                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "For what <plural form of X title> are the maximum value less than <N> units?"
                        st = st.replace("<plural form of X title>",js['task7']['x_label'])
                        med_lst = list()
                        data_list = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append(j['max'])
                                data_list.append([j['x'],j['max']])
                        N = random.uniform(min(med_lst),max(med_lst))
                        answers_list = list()
                        for i in data_list:
                            if i[1]<N:
                                answers_list.append(i[0])
                        if len(answers_list)!=0:
                            q=dict()
                            q['taxonomy id'] = '4b'
                            q['QID'] = '162a'
                            q['question'] = st.replace("<N> units",str(N))
                            q['answer'] = tuple(answers_list)
                            qa.append(q)
                            
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "What <plural form of X title> have the maximum value less than <N> units, arranged in increasing order of difference between maximum value and <N> units?"
                        st = st.replace("<plural form of X title>",js['task7']['x_label'])
                        med_lst = list()
                        data_list = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append(j['max'])
                                data_list.append([j['x'],j['max']])
                        N = random.uniform(min(med_lst),max(med_lst))
                        answers_list_temp = list()
                        for i in data_list:
                            if i[1]<N:
                                answers_list_temp.append([i[0],abs(i[1]-N)])
                        answers_list_temp = sorted(answers_list_temp,key = lambda x:x[1])
                        answers_list = list()
                        for i in answers_list_temp:
                            answers_list.append(i[0])
                        if len(answers_list)!=0:
                            q=dict()
                            q['taxonomy id'] = '4b'
                            q['QID'] = '162b'
                            q['question'] = st.replace("<N> units",str(N))
                            q['answer'] = tuple(answers_list)
                            qa.append(q)
                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "In how many <plural form of X title>, is the minimum value less than <N> units?"
                        st = st.replace("<plural form of X title>",js['task7']['x_label'])
                        med_lst = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append(j['min'])
                        N = random.uniform(min(med_lst),max(med_lst))
                        q=dict()
                        q['taxonomy id'] = '4b'
                        q['QID'] = str(163)
                        q['question'] = st.replace("<N> units",str(N))
                        count = 0
                        for i in med_lst:
                            if i<N:
                                count+=1
                        q['answer'] = count
                        qa.append(q)
                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "For what <plural form of X title> are the minimum value less than <N> units?"
                        st = st.replace("<plural form of X title>",js['task7']['x_label'])
                        med_lst = list()
                        data_list = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append(j['min'])
                                data_list.append([j['x'],j['min']])
                        N = random.uniform(min(med_lst),max(med_lst))
                        answers_list = list()
                        for i in data_list:
                            if i[1]<N:
                                answers_list.append(i[0])
                        if len(answers_list)!=0:
                            q=dict()
                            q['taxonomy id'] = '4b'
                            q['QID'] = '163a'
                            q['question'] = st.replace("<N> units",str(N))
                            q['answer'] = tuple(answers_list)
                            qa.append(q)
                            
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_label' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "What <plural form of X title> have the minimum value less than <N> units, arranged in increasing order of difference between minimum value and <N> units?"
                        st = st.replace("<plural form of X title>",js['task7']['x_label'])
                        med_lst = list()
                        data_list = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append(j['min'])
                                data_list.append([j['x'],j['min']])
                        N = random.uniform(min(med_lst),max(med_lst))
                        answers_list_temp = list()
                        for i in data_list:
                            if i[1]<N:
                                answers_list_temp.append([i[0],abs(i[1]-N)])
                        answers_list_temp = sorted(answers_list_temp,key = lambda x:x[1])
                        answers_list = list()
                        for i in answers_list_temp:
                            answers_list.append(i[0])
                        if len(answers_list)!=0:
                            q=dict()
                            q['taxonomy id'] = '4b'
                            q['QID'] = '163b'
                            q['question'] = st.replace("<N> units",str(N))
                            q['answer'] = tuple(answers_list)
                            qa.append(q)
                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_ticks_from_left' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "What is the ratio of upper and lower quartile value at <ith x-tick>?"
                        ticks = js['task7']['x_ticks_from_left']
                        ls_dat = list()
                        for i in ticks:
                            for i1 in js['task6']['output']['data series']:
                                for j in i1['data']:
                                    if j['x'].split() == i.split():
                                        val1 = j['third_quartile']
                                        val2 = j['first_quartile']
                                        if val2!=0:
                                            q=dict()
                                            q['taxonomy id'] = '4b'
                                            q['QID'] = str(164)
                                            q['question'] = st.replace("<ith x-tick>",i)
                                            q['answer'] = val1/val2
                                            qa.append(q)
                                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and js['task6']!=None and 'x_ticks_from_left' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "What is the ratio of maximum and minimum value at <ith x-tick>?"
                        ticks = js['task7']['x_ticks_from_left']
                        ls_dat = list()
                        for i in ticks:
                            for i1 in js['task6']['output']['data series']:
                                for j in i1['data']:
                                    if j['x'].split() == i.split():
                                        val1 = j['max']
                                        val2 = j['min']
                                        if val2!=0:
                                            q=dict()
                                            q['taxonomy id'] = '4b'
                                            q['QID'] = str(165)
                                            q['question'] = st.replace("<ith x-tick>",i)
                                            q['answer'] = val1/val2
                                            qa.append(q)
                                        
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_ticks_from_left' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Is the value of median of <Y-label> at < ith x tick> less than that at < jth x tick>?"
                        st = st.replace("<Y-label>",js['task7']['y_label'])
                        ticks = js['task7']['x_ticks_from_left']
                        for i in range(len(ticks)-1):
                            for j in range(i+1,len(ticks)):
                                for i1 in js['task6']['output']['data series']:
                                    for j1 in i1['data']:
                                        if ticks[i].split() == j1['x'].split():
                                            val1 = j1['median']
                                        elif ticks[j].split() == j1['x'].split():
                                            val2 = j1['median']
                                qu = st.replace("< ith x tick>",ticks[i])
                                q=dict()
                                q['taxonomy id'] = '4b'
                                q['QID'] = str(166)
                                q['question'] = qu.replace("< jth x tick>",ticks[j])
                                q['answer'] = "yes" if val1<val2 else "no"
                                qa.append(q)
                                
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_ticks_from_left' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Which major ticks has the value of median less than that at <ith x tick>?"
                        ticks = js['task7']['x_ticks_from_left']
                        med_lst = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append([j['x'],j['median']])
                        for t in ticks:
                            ans = list()
                            for i in js['task6']['output']['data series']:
                                for j in i['data']:
                                    if t.split() == j['x'].split():
                                        val = j['median']
                            for i in med_lst:
                                if i[1]<val:
                                    ans.append(i[0])
                            if len(ans)!=0:
                                q=dict()
                                q['taxonomy id'] = '4b'
                                q['QID'] = '166a'
                                q['question'] = st.replace("<ith x tick>",t)
                                q['answer'] = ans
                                qa.append(q)
                            
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_ticks_from_left' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Which major ticks has the value of median less than that at <ith x tick>,arranged in the increasing order of difference between the medians?"
                        ticks = js['task7']['x_ticks_from_left']
                        med_lst = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append([j['x'],j['median']])
                        for t in ticks:
                            ans = list()
                            for i in js['task6']['output']['data series']:
                                for j in i['data']:
                                    if t.split() == j['x'].split():
                                        val = j['median']
                            for i in med_lst:
                                if i[1]<val:
                                    ans.append([i[0],abs(i[1]-val)])
                            final_temp = sorted(ans,key=lambda x:x[1])
                            final_ans = list()
                            for a in final_temp:
                                final_ans.append(a[0])
                            if len(final_ans)!=0:
                                q=dict()
                                q['taxonomy id'] = '4b'
                                q['QID'] = '166c'
                                q['question'] = st.replace("<ith x tick>",t)
                                q['answer'] = final_ans
                                qa.append(q)
                            
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_ticks_from_left' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Which major ticks has the value of median greater than that at <ith x tick>?"
                        ticks = js['task7']['x_ticks_from_left']
                        med_lst = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append([j['x'],j['median']])
                        for t in ticks:
                            ans = list()
                            for i in js['task6']['output']['data series']:
                                for j in i['data']:
                                    if t.split() == j['x'].split():
                                        val = j['median']
                            for i in med_lst:
                                if i[1]>val:
                                    ans.append(i[0])
                            if len(ans)!=0:
                                q=dict()
                                q['taxonomy id'] = '4b'
                                q['QID'] = '166b'
                                q['question'] = st.replace("<ith x tick>",t)
                                q['answer'] = ans
                                qa.append(q)
                            
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_ticks_from_left' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Which major ticks has the value of median greater than that at <ith x tick>,arranged in the increasing order of difference between the medians?"
                        ticks = js['task7']['x_ticks_from_left']
                        med_lst = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append([j['x'],j['median']])
                        for t in ticks:
                            ans = list()
                            for i in js['task6']['output']['data series']:
                                for j in i['data']:
                                    if t.split() == j['x'].split():
                                        val = j['median']
                            for i in med_lst:
                                if i[1]>val:
                                    ans.append([i[0],abs(i[1]-val)])
                            final_temp = sorted(ans,key=lambda x:x[1])
                            final_ans = list()
                            for a in final_temp:
                                final_ans.append(a[0])
                            if len(final_ans)!=0:
                                q=dict()
                                q['taxonomy id'] = '4b'
                                q['QID'] = '166d'
                                q['question'] = st.replace("<ith x tick>",t)
                                q['answer'] = final_ans
                                qa.append(q)
                                
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_ticks_from_left' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Is the value of upper quartile of <Y-label> at < ith x tick> less than that at < jth x tick>?"
                        st = st.replace("<Y-label>",js['task7']['y_label'])
                        ticks = js['task7']['x_ticks_from_left']
                        for i in range(len(ticks)-1):
                            for j in range(i+1,len(ticks)):
                                for i1 in js['task6']['output']['data series']:
                                    for j1 in i1['data']:
                                        if ticks[i].split() == j1['x'].split():
                                            val1 = j1['third_quartile']
                                        elif ticks[j].split() == j1['x'].split():
                                            val2 = j1['third_quartile']
                                qu = st.replace("< ith x tick>",ticks[i])
                                q=dict()
                                q['taxonomy id'] = '4b'
                                q['QID'] = str(167)
                                q['question'] = qu.replace("< jth x tick>",ticks[j])
                                q['answer'] = "yes" if val1<val2 else "no"
                                qa.append(q)
                                
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_ticks_from_left' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Which major ticks has the value of upper quartile less than that at <ith x tick>?"
                        ticks = js['task7']['x_ticks_from_left']
                        med_lst = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append([j['x'],j['third_quartile']])
                        for t in ticks:
                            ans = list()
                            for i in js['task6']['output']['data series']:
                                for j in i['data']:
                                    if t.split() == j['x'].split():
                                        val = j['third_quartile']
                            for i in med_lst:
                                if i[1]<val:
                                    ans.append(i[0])
                            if len(ans)!=0:
                                q=dict()
                                q['taxonomy id'] = '4b'
                                q['QID'] = '167a'
                                q['question'] = st.replace("<ith x tick>",t)
                                q['answer'] = ans
                                qa.append(q)
                            
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_ticks_from_left' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Which major ticks has the value of upper quartile less than that at <ith x tick>,arranged in the increasing order of difference between the upper quartiles?"
                        ticks = js['task7']['x_ticks_from_left']
                        med_lst = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append([j['x'],j['third_quartile']])
                        for t in ticks:
                            ans = list()
                            for i in js['task6']['output']['data series']:
                                for j in i['data']:
                                    if t.split() == j['x'].split():
                                        val = j['third_quartile']
                            for i in med_lst:
                                if i[1]<val:
                                    ans.append([i[0],abs(i[1]-val)])
                            final_temp = sorted(ans,key = lambda x:x[1])
                            final_ans = list()
                            for a in final_temp:
                                final_ans.append(a[0])
                            if len(final_ans)!=0:
                                q=dict()
                                q['taxonomy id'] = '4b'
                                q['QID'] = '167c'
                                q['question'] = st.replace("<ith x tick>",t)
                                q['answer'] = final_ans
                                qa.append(q)
                            
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_ticks_from_left' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Which major ticks has the value of upper quartile greater than that at <ith x tick>?"
                        ticks = js['task7']['x_ticks_from_left']
                        med_lst = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append([j['x'],j['third_quartile']])
                        for t in ticks:
                            ans = list()
                            for i in js['task6']['output']['data series']:
                                for j in i['data']:
                                    if t.split() == j['x'].split():
                                        val = j['third_quartile']
                            for i in med_lst:
                                if i[1]>val:
                                    ans.append(i[0])
                            if len(ans)!=0:
                                q=dict()
                                q['taxonomy id'] = '4b'
                                q['QID'] = '167b'
                                q['question'] = st.replace("<ith x tick>",t)
                                q['answer'] = ans
                                qa.append(q)
                            
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_ticks_from_left' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Which major ticks has the value of upper quartile greater than that at <ith x tick>,arranged in the increasing order of difference between the upper quartiles?"
                        ticks = js['task7']['x_ticks_from_left']
                        med_lst = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append([j['x'],j['third_quartile']])
                        for t in ticks:
                            ans = list()
                            for i in js['task6']['output']['data series']:
                                for j in i['data']:
                                    if t.split() == j['x'].split():
                                        val = j['third_quartile']
                            for i in med_lst:
                                if i[1]>val:
                                    ans.append([i[0],abs(i[1]-val)])
                            final_temp = sorted(ans,key = lambda x:x[1])
                            final_ans = list()
                            for a in final_temp:
                                final_ans.append(a[0])
                            if len(final_ans)!=0:
                                q=dict()
                                q['taxonomy id'] = '4b'
                                q['QID'] = '167d'
                                q['question'] = st.replace("<ith x tick>",t)
                                q['answer'] = final_ans
                                qa.append(q)
                                
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_ticks_from_left' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Is the value of lower quartile of <Y-label> at < ith x tick> less than that at < jth x tick>?"
                        st = st.replace("<Y-label>",js['task7']['y_label'])
                        ticks = js['task7']['x_ticks_from_left']
                        for i in range(len(ticks)-1):
                            for j in range(i+1,len(ticks)):
                                for i1 in js['task6']['output']['data series']:
                                    for j1 in i1['data']:
                                        if ticks[i].split() == j1['x'].split():
                                            val1 = j1['first_quartile']
                                        elif ticks[j].split() == j1['x'].split():
                                            val2 = j1['first_quartile']
                                qu = st.replace("< ith x tick>",ticks[i])
                                q=dict()
                                q['taxonomy id'] = '4b'
                                q['QID'] = str(168)
                                q['question'] = qu.replace("< jth x tick>",ticks[j])
                                q['answer'] = "yes" if val1<val2 else "no"
                                qa.append(q)
                                
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_ticks_from_left' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Which major ticks has the value of lower quartile less than that at <ith x tick>?"
                        ticks = js['task7']['x_ticks_from_left']
                        med_lst = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append([j['x'],j['first_quartile']])
                        for t in ticks:
                            ans = list()
                            for i in js['task6']['output']['data series']:
                                for j in i['data']:
                                    if t.split() == j['x'].split():
                                        val = j['first_quartile']
                            for i in med_lst:
                                if i[1]<val:
                                    ans.append(i[0])
                            if len(ans)!=0:
                                q=dict()
                                q['taxonomy id'] = '4b'
                                q['QID'] = '168a'
                                q['question'] = st.replace("<ith x tick>",t)
                                q['answer'] = ans
                                qa.append(q)
                            
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_ticks_from_left' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Which major ticks has the value of lower quartile less than that at <ith x tick>,arranged in the increasing order of difference between the lower quartiles?"
                        ticks = js['task7']['x_ticks_from_left']
                        med_lst = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append([j['x'],j['first_quartile']])
                        for t in ticks:
                            ans = list()
                            for i in js['task6']['output']['data series']:
                                for j in i['data']:
                                    if t.split() == j['x'].split():
                                        val = j['first_quartile']
                            for i in med_lst:
                                if i[1]<val:
                                    ans.append([i[0],abs(i[1]-val)])
                            final_temp = sorted(ans,key=lambda x:x[1])
                            final_ans = list()
                            for a in final_temp:
                                final_ans.append(a[0])
                            if len(final_ans)!=0:
                                q=dict()
                                q['taxonomy id'] = '4b'
                                q['QID'] = '168c'
                                q['question'] = st.replace("<ith x tick>",t)
                                q['answer'] = final_ans
                                qa.append(q)
                            
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_ticks_from_left' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Which major ticks has the value of lower quartile greater than that at <ith x tick>?"
                        ticks = js['task7']['x_ticks_from_left']
                        med_lst = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append([j['x'],j['first_quartile']])
                        for t in ticks:
                            ans = list()
                            for i in js['task6']['output']['data series']:
                                for j in i['data']:
                                    if t.split() == j['x'].split():
                                        val = j['first_quartile']
                            for i in med_lst:
                                if i[1]>val:
                                    ans.append(i[0])
                            if len(ans)!=0:
                                q=dict()
                                q['taxonomy id'] = '4b'
                                q['QID'] = '168b'
                                q['question'] = st.replace("<ith x tick>",t)
                                q['answer'] = ans
                                qa.append(q)
                            
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_ticks_from_left' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Which major ticks has the value of lower quartile greater than that at <ith x tick>,arranged in the increasing order of difference between the lower quartiles?"
                        ticks = js['task7']['x_ticks_from_left']
                        med_lst = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append([j['x'],j['first_quartile']])
                        for t in ticks:
                            ans = list()
                            for i in js['task6']['output']['data series']:
                                for j in i['data']:
                                    if t.split() == j['x'].split():
                                        val = j['first_quartile']
                            for i in med_lst:
                                if i[1]>val:
                                    ans.append([i[0],abs(i[1]-val)])
                            final_temp = sorted(ans,key=lambda x:x[1])
                            final_ans = list()
                            for a in final_temp:
                                final_ans.append(a[0])
                            if len(final_ans)!=0:
                                q=dict()
                                q['taxonomy id'] = '4b'
                                q['QID'] = '168d'
                                q['question'] = st.replace("<ith x tick>",t)
                                q['answer'] = final_ans
                                qa.append(q)
                                
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_ticks_from_left' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Is the maximum value of <Y-label> at < ith x tick> less than that at < jth x tick>?"
                        st = st.replace("<Y-label>",js['task7']['y_label'])
                        ticks = js['task7']['x_ticks_from_left']
                        for i in range(len(ticks)-1):
                            for j in range(i+1,len(ticks)):
                                for i1 in js['task6']['output']['data series']:
                                    for j1 in i1['data']:
                                        if ticks[i].split() == j1['x'].split():
                                            val1 = j1['max']
                                        elif ticks[j].split() == j1['x'].split():
                                            val2 = j1['max']
                                qu = st.replace("< ith x tick>",ticks[i])
                                q=dict()
                                q['taxonomy id'] = '4b'
                                q['QID'] = str(169)
                                q['question'] = qu.replace("< jth x tick>",ticks[j])
                                q['answer'] = "yes" if val1<val2 else "no"
                                qa.append(q)
                                
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_ticks_from_left' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Which major ticks has the maximum value less than that at <ith x tick>?"
                        ticks = js['task7']['x_ticks_from_left']
                        med_lst = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append([j['x'],j['max']])
                        for t in ticks:
                            ans = list()
                            for i in js['task6']['output']['data series']:
                                for j in i['data']:
                                    if t.split() == j['x'].split():
                                        val = j['max']
                            for i in med_lst:
                                if i[1]<val:
                                    ans.append(i[0])
                            if len(ans)!=0:
                                q=dict()
                                q['taxonomy id'] = '4b'
                                q['QID'] = '169a'
                                q['question'] = st.replace("<ith x tick>",t)
                                q['answer'] = ans
                                qa.append(q)
                            
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_ticks_from_left' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Which major ticks has the maximum value less than that at <ith x tick>,arranged in the increasing order of difference between the maximum values?"
                        ticks = js['task7']['x_ticks_from_left']
                        med_lst = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append([j['x'],j['max']])
                        for t in ticks:
                            ans = list()
                            for i in js['task6']['output']['data series']:
                                for j in i['data']:
                                    if t.split() == j['x'].split():
                                        val = j['max']
                            for i in med_lst:
                                if i[1]<val:
                                    ans.append([i[0],abs(i[1]-val)])
                            final_temp = sorted(ans,key=lambda x:x[1])
                            final_ans = list()
                            for a in final_temp:
                                final_ans.append(a[0])
                            if len(final_ans)!=0:
                                q=dict()
                                q['taxonomy id'] = '4b'
                                q['QID'] = '169c'
                                q['question'] = st.replace("<ith x tick>",t)
                                q['answer'] = final_ans
                                qa.append(q)
                            
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_ticks_from_left' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Which major ticks has the maximum value greater than that at <ith x tick>?"
                        ticks = js['task7']['x_ticks_from_left']
                        med_lst = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append([j['x'],j['max']])
                        for t in ticks:
                            ans = list()
                            for i in js['task6']['output']['data series']:
                                for j in i['data']:
                                    if t.split() == j['x'].split():
                                        val = j['max']
                            for i in med_lst:
                                if i[1]>val:
                                    ans.append(i[0])
                            if len(ans)!=0:
                                q=dict()
                                q['taxonomy id'] = '4b'
                                q['QID'] = '169b'
                                q['question'] = st.replace("<ith x tick>",t)
                                q['answer'] = ans
                                qa.append(q)
                            
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_ticks_from_left' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Which major ticks has the maximum value greater than that at <ith x tick>,arranged in the increasing order of difference between the maximum values?"
                        ticks = js['task7']['x_ticks_from_left']
                        med_lst = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append([j['x'],j['max']])
                        for t in ticks:
                            ans = list()
                            for i in js['task6']['output']['data series']:
                                for j in i['data']:
                                    if t.split() == j['x'].split():
                                        val = j['max']
                            for i in med_lst:
                                if i[1]>val:
                                    ans.append([i[0],abs(i[1]-val)])
                            final_temp = sorted(ans,key=lambda x:x[1])
                            final_ans = list()
                            for a in final_temp:
                                final_ans.append(a[0])
                            if len(final_ans)!=0:
                                q=dict()
                                q['taxonomy id'] = '4b'
                                q['QID'] = '169d'
                                q['question'] = st.replace("<ith x tick>",t)
                                q['answer'] = final_ans
                                qa.append(q)
                                
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_ticks_from_left' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Is the minimum value of <Y-label> at < ith x tick> less than that at < jth x tick>?"
                        st = st.replace("<Y-label>",js['task7']['y_label'])
                        ticks = js['task7']['x_ticks_from_left']
                        for i in range(len(ticks)-1):
                            for j in range(i+1,len(ticks)):
                                for i1 in js['task6']['output']['data series']:
                                    for j1 in i1['data']:
                                        if ticks[i].split() == j1['x'].split():
                                            val1 = j1['min']
                                        elif ticks[j].split() == j1['x'].split():
                                            val2 = j1['min']
                                qu = st.replace("< ith x tick>",ticks[i])
                                q=dict()
                                q['taxonomy id'] = '4b'
                                q['QID'] = str(170)
                                q['question'] = qu.replace("< jth x tick>",ticks[j])
                                q['answer'] = "yes" if val1<val2 else "no"
                                qa.append(q)
                                
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_ticks_from_left' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Which major ticks has the minimum value less than that at <ith x tick>?"
                        ticks = js['task7']['x_ticks_from_left']
                        med_lst = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append([j['x'],j['min']])
                        for t in ticks:
                            ans = list()
                            for i in js['task6']['output']['data series']:
                                for j in i['data']:
                                    if t.split() == j['x'].split():
                                        val = j['min']
                            for i in med_lst:
                                if i[1]<val:
                                    ans.append(i[0])
                            if len(ans)!=0:
                                q=dict()
                                q['taxonomy id'] = '4b'
                                q['QID'] = '170a'
                                q['question'] = st.replace("<ith x tick>",t)
                                q['answer'] = ans
                                qa.append(q)
                            
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_ticks_from_left' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Which major ticks has the minimum value less than that at <ith x tick>,arranged in the increasing order of difference between the minimum values?"
                        ticks = js['task7']['x_ticks_from_left']
                        med_lst = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append([j['x'],j['min']])
                        for t in ticks:
                            ans = list()
                            for i in js['task6']['output']['data series']:
                                for j in i['data']:
                                    if t.split() == j['x'].split():
                                        val = j['min']
                            for i in med_lst:
                                if i[1]<val:
                                    ans.append([i[0],abs(i[1]-val)])
                            final_temp = sorted(ans,key=lambda x:x[1])
                            final_ans = list()
                            for a in final_temp:
                                final_ans.append(a[0])
                            if len(final_ans)!=0:
                                q=dict()
                                q['taxonomy id'] = '4b'
                                q['QID'] = '170c'
                                q['question'] = st.replace("<ith x tick>",t)
                                q['answer'] = final_ans
                                qa.append(q)
                            
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_ticks_from_left' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Which major ticks has the minimum value greater than that at <ith x tick>?"
                        ticks = js['task7']['x_ticks_from_left']
                        med_lst = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append([j['x'],j['min']])
                        for t in ticks:
                            ans = list()
                            for i in js['task6']['output']['data series']:
                                for j in i['data']:
                                    if t.split() == j['x'].split():
                                        val = j['min']
                            for i in med_lst:
                                if i[1]>val:
                                    ans.append(i[0])
                            if len(ans)!=0:
                                q=dict()
                                q['taxonomy id'] = '4b'
                                q['QID'] = '170b'
                                q['question'] = st.replace("<ith x tick>",t)
                                q['answer'] = ans
                                qa.append(q)
                            
            if 'task7' in js.keys() and 'task6' in js.keys():
                if 'figure_type' in js['task7'].keys() and 'y_label' in js['task7'].keys() and js['task6']!=None and 'x_ticks_from_left' in js['task7'].keys() and 'legends' not in js['task7'].keys() and len(js['task7']['name_of_data_series'])==1:
                    if js['task7']['figure_type'] == 'boxplots':
                        st = "Which major ticks has the minimum value greater than that at <ith x tick>,arranged in the increasing order of difference between the minimum values?"
                        ticks = js['task7']['x_ticks_from_left']
                        med_lst = list()
                        for i in js['task6']['output']['data series']:
                            for j in i['data']:
                                med_lst.append([j['x'],j['min']])
                        for t in ticks:
                            ans = list()
                            for i in js['task6']['output']['data series']:
                                for j in i['data']:
                                    if t.split() == j['x'].split():
                                        val = j['min']
                            for i in med_lst:
                                if i[1]>val:
                                    ans.append([i[0],abs(i[1]-val)])
                            final_temp = sorted(ans,key=lambda x:x[1])
                            final_ans = list()
                            for a in final_temp:
                                final_ans.append(a[0])
                            if len(final_ans)!=0:
                                q=dict()
                                q['taxonomy id'] = '4b'
                                q['QID'] = '170d'
                                q['question'] = st.replace("<ith x tick>",t)
                                q['answer'] = final_ans
                                qa.append(q)
                                
            if 'task7' in js.keys():
                st = "Is independent axis categorical or numerical?"
                ticks = list()
                if 'x_ticks_from_left' in js['task7'].keys(): 
                    ticks = js['task7']['x_ticks_from_left']
                elif 'x_ticks_from_top' in js['task7'].keys():
                    ticks = js['task7']['x_ticks_from_top']
                if len(ticks)!=0:
                    q=dict()
                    q['taxonomy id'] = '2a'
                    q['QID'] = str(79)
                    q['question'] = st
                    f=1
                    for i in ticks:
                        try:
                            ti = float(i)
                        except:
                            f=0
                            break
                    q['answer'] = 'numerical' if f==1 else 'categorical'
                    qa.append(q)
                    
            if 'task7' in js.keys():
                st = "What is the maximum value on independent axis?"
                ticks = list()
                if 'x_ticks_from_left' in js['task7'].keys(): 
                    ticks = js['task7']['x_ticks_from_left']
                elif 'x_ticks_from_top' in js['task7'].keys():
                    ticks = js['task7']['x_ticks_from_top']
                if len(ticks)!=0:
                    q=dict()
                    q['taxonomy id'] = '2a'
                    q['QID'] = str(80)
                    q['question'] = st
                    f=1
                    tic_x = list()
                    for i in ticks:
                        try:
                            tic_x.append(float(i))
                        except:
                            f=0
                            break
                    if f==1:
                        q['answer'] = max(tic_x)
                        qa.append(q)
                        
            if 'task7' in js.keys():
                st = "What is the starting value on independent axis?"
                ticks = list()
                if 'x_ticks_from_left' in js['task7'].keys(): 
                    ticks = js['task7']['x_ticks_from_left']
                elif 'x_ticks_from_top' in js['task7'].keys():
                    ticks = js['task7']['x_ticks_from_top']
                if len(ticks)!=0:
                    q=dict()
                    q['taxonomy id'] = '2a'
                    q['QID'] = str(81)
                    q['question'] = st
                    f=1
                    tic_x = list()
                    for i in ticks:
                        try:
                            tic_x.append(float(i))
                        except:
                            f=0
                            break
                    if f==1:
                        q['answer'] = min(tic_x)
                        qa.append(q)
                        
            if 'task7' in js.keys():
                st = "What is the starting value on dependent axis?"
                ticks = list()
                if 'y_ticks_from_left' in js['task7'].keys(): 
                    ticks = js['task7']['y_ticks_from_left']
                elif 'y_ticks_from_top' in js['task7'].keys():
                    ticks = js['task7']['y_ticks_from_top']
                if len(ticks)!=0:
                    q=dict()
                    q['taxonomy id'] = '2c'
                    q['QID'] = str(86)
                    q['question'] = st
                    f=1
                    tic_x = list()
                    for i in ticks:
                        try:
                            tic_x.append(float(i))
                        except:
                            f=0
                            break
                    if f==1:
                        q['answer'] = min(tic_x)
                        qa.append(q)
                        
            if 'task7' in js.keys() and 'task3' in js.keys():
                if js['task3']!=None:
                    q=dict()
                    q['taxonomy id'] = '2e'
                    q['QID'] = str(89)
                    q['question'] = 'Is there a legend title?'
                    f=1
                    for i in js['task3']['output']['text_roles']:
                        if i['role'] == 'legend_title':
                            f=0
                    q['answer'] = 'yes' if f==0 else 'no'
                    qa.append(q)
                    
            if 'task7' in js.keys() and 'task3' in js.keys() and 'task2' in js.keys():
                if js['task3']!=None and js['task2']!=None:
                    q=dict()
                    q['taxonomy id'] = '2e'
                    q['QID'] = str(90)
                    q['question'] = 'What is the title of legend?'
                    f=1
                    for i in js['task3']['output']['text_roles']:
                        if i['role'] == 'legend_title':
                            f=0
                            iden = i['id']
                    if f==0:
                        for i in js['task2']['output']['text_blocks']:
                            if i['id'] == iden:
                                tit = i['text']
                        q['answer'] = tit
                        qa.append(q)
                        
            if 'task3' in js.keys():
                if js['task3']!=None:
                    q=dict()
                    q['taxonomy id'] = '2i'
                    q['QID'] = str(91)
                    q['question'] = "Other than the graph objects, is there any other text present on the graph plot area?"
                    flag = 1
                    lst_flag = ['legend_label','axis_title','tick_label','chart_title','legend_title']
                    for i in js['task3']['output']['text_roles']:
                        if i['role'] not in lst_flag:
                            flag = 0
                    q['answer'] = 'yes' if flag==0 else 'no'
                    qa.append(q)
                    
            if 'task3' in js.keys() and 'task2' in js.keys():
                if js['task3']!=None and js['task2']!=None:
                    flag = 1
                    iden = list()
                    lst_flag = ['legend_label','axis_title','tick_label','chart_title','legend_title']
                    for i in js['task3']['output']['text_roles']:
                        if i['role'] not in lst_flag:
                            flag = 0
                            iden.append(i['id'])
                    if flag==0:
                        ans = list()
                        for i in js['task2']['output']['text_blocks']:
                            if i['id'] in iden:
                                ans.append(i['text'])
                        q=dict()
                        q['taxonomy id'] = '2i'
                        q['QID'] = '91a'
                        q['question'] = "Other than the graph objects, what other text are present on the graph plot area?"
                        q['answer'] = ans
                        qa.append(q)
                    
            if 'task7' in js.keys() and 'task2' in js.keys():
                if 'x_label' in js['task7'].keys() and js['task2']!=None:
                    x_lab = js['task7']['x_label']
                    for i in js['task2']['output']['text_blocks']:
                        if i['text'] == x_lab:
                            w,h = abs(i['polygon']['x0'] - i['polygon']['x1']),abs(i['polygon']['y0'] - i['polygon']['y2'])
                    q=dict()
                    q['taxonomy id'] = '2a'
                    q['QID'] = str(82)
                    q['question'] = "What is the orientation of the text of independent axis title?"
                    q['answer'] = "Horizontal" if w>=h else "Vertical"
                    qa.append(q)
                    
            if 'task7' in js.keys() and 'task2' in js.keys():
                if 'y_label' in js['task7'].keys() and js['task2']!=None:
                    y_lab = js['task7']['y_label']
                    for i in js['task2']['output']['text_blocks']:
                        if i['text'] == y_lab:
                            w,h = abs(i['polygon']['x0'] - i['polygon']['x1']),abs(i['polygon']['y0'] - i['polygon']['y2'])
                    q=dict()
                    q['taxonomy id'] = '2c'
                    q['QID'] = str(87)
                    q['question'] = "What is the orientation of text of dependent axis title?"
                    q['answer'] = "Horizontal" if w>=h else "Vertical"
                    qa.append(q)
                    
            if 'task7' in js.keys():
                if 'figure_type' in js['task7'].keys():
                    ticks = list()
                    if 'y_ticks_from_left' in js['task7'].keys():
                        ticks = js['task7']['y_ticks_from_left']
                    elif 'y_ticks_from_top' in js['task7'].keys():
                        ticks = js['task7']['y_ticks_from_top']
                    if len(ticks)!=0:
                        q=dict()
                        q['taxonomy id'] = '2c'
                        q['QID'] = str(85)
                        q['question'] = "Is dependent axis on a logarithmic scale or Linear scale?"
                        tick_lst = list()
                        for i in ticks:
                            try:
                                tick_lst.append(float(i))
                            except:
                                pass
                        if len(tick_lst)!=0:
                            diff = list()
                            for i in range(len(tick_lst)-1):
                                diff.append(abs(tick_lst[i+1]-tick_lst[i]))
                            q['answer'] = 'Linear' if all(x in [diff[0],diff[0]+1,diff[0]-1] for x in diff) else 'Logarithmic'
                            qa.append(q)
            
        obj = json.dumps(qa,indent = 4)
        with open(qa_folder+file,'w') as f1:
            f1.write(obj)

# %%
for i in lst_of_folders:
    qa_folder = "C:/Users/pande/Desktop/test_2023/QA/"+i+"_qa/"
    for j in os.listdir(qa_folder):
        with open(qa_folder+j,'r') as f:
            js = json.load(f)
            for k in js:
                k['QID'] = str(k['QID'])
                k['question'] = k['question'].replace("\n"," ")
                if type(k['answer']) == str:
                    k['answer'] = k['answer'].replace("\n"," ")
        os.remove(qa_folder+j)
        with open(qa_folder+j, 'w') as f:
            json.dump(js, f, indent=4)

# %%
import re
for i in lst_of_folders:
    qa_folder = "C:/Users/pande/Desktop/test_2023/QA/"      # path for QA folder
    for j in os.listdir(qa_folder+i+"_qa/"):
        with open(qa_folder+i+"_qa/"+j) as f:
            js = json.load(f)
            for k in js:
                k['question'] = re.sub(r"[\n]", " ", k['question'])
                if type(k['answer']) == str:
                    k['answer'] = re.sub(r"[\n]", " ", k['answer'])
                elif type(k['answer']) == list:
                    lst = list()
                    for a in k['answer']:
                        if type(a) == str:
                            a = re.sub(r"[\n]", " ", a)
                            lst.append(a)
                            k['answer'] = lst
        os.remove(qa_folder+i+"_qa/"+j)
        with open(qa_folder+i+"_qa/"+j, 'w') as f:
            json.dump(js, f, indent=4)

# %%
df = pd.read_csv("C:/Users/pande/Desktop/template.csv")
df = pd.DataFrame(df)
for k in lst_of_folders:
    qa_folder = "C:/Users/pande/Desktop/test_2023/QA/"      # path for QA folder
    for j in os.listdir(qa_folder+k+"_qa/"):
        with open(qa_folder+k+"_qa/"+j) as f:
            js = json.load(f)
            for k1 in js:
                k1['answer_type'] = list(df.iloc[np.where(df['qid']==k1['QID'])]['answer_type'])[0]
        os.remove(qa_folder+k+"_qa/"+j)
        with open(qa_folder+k+"_qa/"+j, 'w') as f:
            json.dump(js, f, indent=4)

# %%
for i in lst_of_folders:
    qa_folder = "C:/Users/pande/Desktop/test_2023/QA/"+i+"_qa/"
    for j in os.listdir(qa_folder):
        with open(qa_folder+j,'r') as f:
            js = json.load(f)
            for k in js:
                if k['answer'] == "":
                    print(j)
                elif k['answer'] is None:
                    print(j)
                if 'answer_type' not in k.keys():
                    print(j)
